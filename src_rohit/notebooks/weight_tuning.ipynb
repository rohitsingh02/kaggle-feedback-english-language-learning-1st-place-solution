# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
target_cols = ["cohesion", "syntax", "vocabulary", "phraseology", "grammar", "conventions"]

# %%
import os
# os.listdir("/home/rohits/pv1/feedback_ell/main1/output/csv2")

"../output/csv/microsoft-deberta-v3-base-pl_oof_df.csv",
"../output/final/exp14/roberta-large/oof_df.csv", done
"../output/final/exp13/microsoft-deberta-v3-large/oof_df.csv",
"../output/final/exp02/distilbert-base-uncased/oof_df.csv", done
"/home/rohits/pv1/feedback_ell/main1/output/exp01/microsoft-deberta-v3-base-pldf/oof_df.csv", # 11
"/home/rohits/pv1/feedback_ell/main1/output/exp11/roberta-large/oof_df.csv", done



'/home/rohits/pv1/feedback_ell/main1/output/csv2/fb_bart_large_512_oof.csv',
"/home/rohits/pv1/feedback_ell/main1/output/csv2/ad_v3_roberta_large.csv",
"/home/rohits/pv1/feedback_ell/main1/output/csv2/fb_bart_large_mnli.csv",

# %%
csvs1 = [
    "../output/csv/microsoft-deberta-v3-base-pl_oof_df.csv", # 1 | 0.7055331817915967, | 0.5657800739929426,
    '../output/csv/model23.csv', # 2 | 0.9999997540570867,
    '../output/csv/0926-deberta-v3-large.csv',  # 3 |  0.2368510563835527,
    '../output/csv/nischay.csv', # 4 | 0.1928050320016373,
    '../output/csv/0919-deberta-v2-xlarge-mnli.csv', # 5 |  0.18057453449953897,
    "../output/final/exp14/roberta-large/oof_df.csv",  # 6 | 0.21010949868169015,
    '../output/csv/0911-deberta-v3-large.csv', # 7 | 0.2362832659057783,
    "../output/final/exp13/microsoft-deberta-v3-large/oof_df.csv", # 8 |  0.185625885284853,
    "../output/final/exp02/distilbert-base-uncased/oof_df.csv", # 9 |  0.056289028237849884
    
    "/home/rohits/pv1/feedback_ell/main1/output/csv/model52.csv", # 10
    
    
    
    "/home/rohits/pv1/feedback_ell/main1/output/exp01/microsoft-deberta-v3-base-pldf/oof_df.csv", # 11
    "/home/rohits/pv1/feedback_ell/main1/output/exp11/roberta-large/oof_df.csv",
    
    
    
    
    '../output/csv/model68.csv', 
    '../output/csv/model70.csv',
    '../output/csv/model71.csv', 
    '/home/rohits/pv1/feedback_ell/main1/output/csv2/fb_bart_large_512_oof.csv',
    "/home/rohits/pv1/feedback_ell/main1/output/csv2/ad_v3_roberta_large.csv",
    "/home/rohits/pv1/feedback_ell/main1/output/csv2/fb_bart_large_mnli.csv",
    
#     '../output/csv/model74.csv', 
#     '../output/csv/model81.csv', 
#     '../output/csv/model84.csv', 
    
    
    
#     "../output/csv/model75.csv"
    
    
    
#     "/home/rohits/pv1/feedback_ell/main1/output/csv2/oof_4.csv"
    
    
#     "/home/rohits/pv1/feedback_ell/main1/output/csv/model75.csv"
    
#     "/home/rohits/pv1/feedback_ell/main1/output/exp14/microsoft-deberta-v3-small/oof_df.csv"
    
#     "/home/rohits/pv1/feedback_ell/main1/output/final/exp02/microsoft-deberta-v3-large/oof_df.csv",
#     "/home/rohits/pv1/feedback_ell/main1/output/final/exp12/roberta-large/oof_df.csv"
    
        
    
#     "/home/rohits/pv1/feedback_ell/main1/output/exp31/microsoft-deberta-v3-base/oof_df.csv"
#     '/home/rohits/pv1/feedback_ell/main1/output/final/exp12/roberta-large/oof_df.csv'
#     '/home/rohits/pv1/feedback_ell/main1/output/final/exp02/microsoft-deberta-v3-large/oof_df.csv'
#     '/home/rohits/pv1/feedback_ell/main1/output/exp11/microsoft-deberta-v3-base/oof_df.csv'
#     "/home/rohits/pv1/feedback_ell/main1/output/exp31/microsoft-deberta-v3-base/oof_df.csv"
    
]

# %%
"/home/rohits/pv1/feedback_ell/main1/output/exp11/roberta-large/oof_df.csv",
# Out:
# ('/home/rohits/pv1/feedback_ell/main1/output/exp11/roberta-large/oof_df.csv',)

# %%
len(csvs1)
# Out:
# 22

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error

def MCRMSE(y_trues, y_preds):
    scores = []
    idxes = y_trues.shape[1]
    for i in range(idxes):
        y_true = y_trues[:,i]
        y_pred = y_preds[:,i]
        score = mean_squared_error(y_true, y_pred, squared=False) # RMSE
        scores.append(score)
    mcrmse_score = np.mean(scores)
    return mcrmse_score, scores



def MCRMSE_SINGLE(y_trues, y_preds):
    scores = []
    mcrmse_score = mean_squared_error(y_trues, y_preds, squared=False) # RMSE
    return mcrmse_score, scores



def get_score(y_trues, y_preds, single=False):
    if single:
        mcrmse_score, scores = MCRMSE_SINGLE(y_trues, y_preds)
    else:
        mcrmse_score, scores = MCRMSE(y_trues, y_preds)
    return mcrmse_score, scores

# %%
all_preds = []

target_cols = ["cohesion", "syntax", "vocabulary", "phraseology", "grammar", "conventions"] 
# target_cols = ["conventions"]

labels = None
for index, csv in enumerate(csvs1):
    oof_df = pd.read_csv(csv)
    
    if index == 10:
        oof_df = oof_df.loc[~oof_df.pred_cohesion.isna()]

    oof_df = oof_df.sort_values('text_id').reset_index(drop=True)

    if index==0: 
        print(oof_df.shape)
        df = pd.read_csv(csvs1[0])
        df = df.sort_values('text_id').reset_index(drop=True)
        labels = df[target_cols].values
        

#     print(oof_df.shape)
        
    if f"pred_{target_cols[0]}" in oof_df.columns:        
        preds = oof_df[[f"pred_{c}" for c in target_cols]].values
    else:
        preds = oof_df[target_cols].values
        
    all_preds.append(preds) 
    single=False
    scores = []
    if single:
        score = get_score(labels, preds, single=True)
    else:
        score, scores = get_score(labels, preds)
    print(score, scores)
    
print("*"*100)
print()
# Out:
# (3911, 16)
# 0.4464636966050677 [0.4774522162758472, 0.4409811027238205, 0.41030992074094386, 0.4488400635555907, 0.46349054820628166, 0.4377083281279225]
# 0.44602233482013226 [0.47190105558596557, 0.4408934582319372, 0.4092328675674622, 0.4521371963226755, 0.464614145700662, 0.4373552855120913]
# 0.4548325877750256 [0.48417351985249657, 0.44964943139868785, 0.4196981014482707, 0.45464136817614237, 0.4730027405917249, 0.44783036518283115]
# 0.4588946815387964 [0.4883262818674721, 0.44730911734564865, 0.4217147655816624, 0.45986613364506074, 0.4839236129232686, 0.45222817786966574]
# 0.4675331302554317 [0.49765214277676595, 0.45645114798273506, 0.4327923793687365, 0.4686475170329412, 0.487983294242493, 0.4616723001289181]
# 0.459625977367254 [0.4852677930702217, 0.45080661867510013, 0.41889217539605295, 0.4646356430178369, 0.485038479624519, 0.453115154419794]
# ...

# %%
def minimize_rmse(params):
    preds = None
    for index, val in enumerate(params.keys()):
        if index == 0:
            preds = params[val]*all_preds[0]
        else:
            preds += params[val]*all_preds[index]
    
    
    param_sum = 0
    for key, val in params.items():
        param_sum += val

    preds = preds/param_sum

    
    score, scores = get_score(labels, preds) 
    return score

# %%
import optuna


def objective(trial):
    
    params = {}
    

#     params = {
#     'w1': 0.5512390924087871,
# #     'w1': trial.suggest_float(f'w1', 0, 1), 
# 'w2': 0.782830323575455,
# #     'w2': trial.suggest_float(f'w2', 0, 1), 
# 'w3': 0.0,
# #     'w3': trial.suggest_float(f'w3', 0, 1), 
# 'w4': 0.07844297451328419,
# #     'w4': trial.suggest_float(f'w4', 0, 1), 
# 'w5': 0.09260997506977303,
# #     'w5': trial.suggest_float(f'w5', 0, 1), 
# 'w6': 0.11103054816810035,
# #         'w6': trial.suggest_float(f'w6', 0, 1), 
# 'w7': 0.00591241308688785,
# #     'w7': trial.suggest_float(f'w7', 0, 1), 
# 'w8': 0.0,
# #     'w8': trial.suggest_float(f'w8', 0, 1), 
# 'w9':  0.0,
# #     'w9': trial.suggest_float(f'w9', 0, 1), 
# 'w10': 0.42146661972372224,
# #     'w10': trial.suggest_float(f'w10', 0, 1), 
# 'w11': 0.19943421871220204,
# #         'w11': trial.suggest_float(f'w11', 0, 1), 
# 'w12': 0.0972011200150965,
# #     'w12': trial.suggest_float(f'w12', 0, 1), 
# 'w13': 0.19799129683149883,
# #     'w13': trial.suggest_float(f'w13', 0, 1), 
# 'w14': 0.0,
# #     'w14': trial.suggest_float(f'w14', 0, 1), 
# 'w15': 0.0,  
# #     'w15': trial.suggest_float(f'w15', 0, 1), 
# 'w16': 0.026239008076526054,
# #     'w16': trial.suggest_float(f'w16', 0, 1), 
# 'w17': 0.16403312327066713,
# #     'w17': trial.suggest_float(f'w17', 0, 1), 
# 'w18': 0.0,
# #     'w18': trial.suggest_float(f'w18', 0, 1), 
# 'w19': 0.0,
# #     'w19': trial.suggest_float(f'w19', 0, 1), 
        
#  'w20': 0.0,
# #     'w20': trial.suggest_float(f'w20', 0, 1), 

# 'w21': 0.1266065044452747,
# 'w21': trial.suggest_float(f'w21', 0, 1), 


# }

    

    
    


    
    

    
    


    
    params = {
        
'w1': 0.5512390924087871,
'w2': 0.782830323575455,
'w3': 0.0,
'w4': 0.07844297451328419,
'w5': 0.09260997506977303,
'w6': 0.11103054816810035,
'w7': 0.00591241308688785,
'w8': 0.0,
'w9':  0.0,
'w10': 0.42146661972372224,
'w11': 0.19943421871220204,
'w12': 0.0972011200150965,
'w13': 0.19799129683149883,
'w14': 0.0,
'w15': 0.0,  
'w16': 0.026239008076526054,
'w17': 0.16403312327066713,
'w18': 0.0,
'w19': 0.0,        
'w20': 0.0,
'w21': 0.1266065044452747,
    'w22': trial.suggest_float(f'w22', 0, 1),
    }
    

    
#     for i in range(17):
#         params[f"w{i+1}"] = trial.suggest_float(f'w{i+1}', 0, 1)  
        

    score = minimize_rmse(params)
    return score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=2000)

study.best_params
# Out:
# [I 2022-11-29 13:39:28,419] A new study created in memory with name: no-name-bdd95e76-9073-4eb4-8d8f-67a8e549417d
# [I 2022-11-29 13:39:28,425] Trial 0 finished with value: 0.43443053589950587 and parameters: {'w22': 0.7499467913430227}. Best is trial 0 with value: 0.43443053589950587.
# [I 2022-11-29 13:39:28,428] Trial 1 finished with value: 0.4349822744945061 and parameters: {'w22': 0.9712201849356344}. Best is trial 0 with value: 0.43443053589950587.
# [I 2022-11-29 13:39:28,429] Trial 2 finished with value: 0.4337956785451299 and parameters: {'w22': 0.44667221597232165}. Best is trial 2 with value: 0.4337956785451299.
# [I 2022-11-29 13:39:28,431] Trial 3 finished with value: 0.4335064326284467 and parameters: {'w22': 0.24286112424150763}. Best is trial 3 with value: 0.4335064326284467.
# [I 2022-11-29 13:39:28,432] Trial 4 finished with value: 0.4345723314066421 and parameters: {'w22': 0.8089232057274164}. Best is trial 3 with value: 0.4335064326284467.
# ...

# %%
cohesion_params = {
'w1': 0.0,
'w2': 0.5996729362090075,
'w3': 0.08245806278263888,
'w4': 0.0,
'w5': 0.1376349948635495,
'w6': 0.004790315075331397,
'w7': 0.23567505722227877,
'w8': 0.0,
'w9': 0.0,
'w10': 0.8034974733435801,
'w11': 0.0,
'w12': 0.2715890154475047,
'w13': 0.0,
'w14': 0.0,
'w15': 0.2391662467106172, 
'w16': 0.0,
'w17': 0.14854951127525526,
'w18': 0.2626651720237393,
'w19': 0.0,        
'w20': 0.0,
'w21': 0.17466714126847185,
'w22': 0.15901122143533208
}



syntax_params = {
'w1': 0.0,
'w2': 0.8073247311298009,
'w3': 0.25458395078498885,
'w4': 0.4550377536447317,
'w5': 0.19778432250606162,
'w6': 0.10690825187238122,
'w7': 0.15336746325045983,
'w8': 0.0,
'w9': 0.20196036945950818,
'w10': 0.0,
'w11': 0.18538941185234192,
'w12': 0.3219483437693948,
'w13': 0.0,
'w14': 0.0,
'w15': 0.0,
'w16': 0.0,
'w17': 0.05903183866040781,
'w18': 0.0,
'w19': 0.05142003617024362,        
'w20': 0.0,
'w21': 0.5019820787246845,
'w22': 0.2566523415489515
}




vocabulary_params = {
'w1': 0.0,
'w2': 0.9837490117004544,
'w3': 0.2715222553173371,
'w4': 0.020216848993521736,
'w5': 0.15511317087349977,
'w6': 0.0,
'w7': 0.2636218257798786,
'w8': 0.0,
'w9': 0.0,
'w10': 0.0,
'w11': 0.8357700011019243,
'w12': 0.5013431063278639,
'w13': 0.0,
'w14': 0.0,
'w15': 0.0,
'w16': 0.20317904461432598,
'w17': 0.0,
'w18': 0.441051867905167,
'w19': 0.0,        
'w20': 0.0,
'w21': 0.4452907449637064,
'w22': 0.0
}



phraseology_params = {
'w1': 0.3603504937674748,
'w2': 0.2660507427798915,
'w3': 0.3692693608180048,
'w4': 0.13000550580998513,
'w5': 0.15333474938304523,
'w6': 0.0,
'w7': 0.2816506655104738,
'w8': 0.0,
'w9': 0.15508374488150772,
'w10': 0.0,
'w11': 0.6882081625868712,
'w12': 0.07477533156092903,
'w13': 0.0,
'w14': 0.0,
'w15': 0.0,
'w16': 0.0,
'w17': 0.09655803804675571,
'w18': 0.12504812147193134,
'w19': 0.261392655084144,
'w20': 0.33944033615240626,
'w21': 0.212090241010748,
'w22': 0.10189623017156355
}


grammar_params = {
'w1': 0.1323177365076396,
'w2': 0.6824355146549391,
'w3': 0.42289996010175146,
'w4': 0.0,
'w5': 0.0,
'w6': 0.0,
'w7': 0.17625094365016017,
'w8': 0.15475917381998253,
'w9':  0.0,
'w10': 0.3744401258245389,
'w11': 0.9999985848198654,
'w12': 0.26574933021789554,
'w13': 0.0,
'w14': 0.5432022948006828,
'w15': 0.7728848641913989,  
'w16': 0.0,
'w17': 0.0,
'w18': 0.0,
'w19': 0.04085936603148009,        
'w20': 0.41102906351633556,
'w21': 0.0,
'w22': 0.0
}



conventions_params = {
'w1': 0.5512390924087871,
'w2': 0.782830323575455,
'w3': 0.0,
'w4': 0.07844297451328419,
'w5': 0.09260997506977303,
'w6': 0.11103054816810035,
'w7': 0.00591241308688785,
'w8': 0.0,
'w9':  0.0,
'w10': 0.42146661972372224,
'w11': 0.19943421871220204,
'w12': 0.0972011200150965,
'w13': 0.19799129683149883,
'w14': 0.0,
'w15': 0.0,  
'w16': 0.026239008076526054,
'w17': 0.16403312327066713,
'w18': 0.0,
'w19': 0.0,        
'w20': 0.0,
'w21': 0.1266065044452747,
'w22': 0.04818617370750301
}

# %%
# cohesion_params = {
# 'w1': 0.0,
# 'w2': 0.615064444433304,
# 'w3': 0.09321178428328165,
# 'w4': 0.0,
# 'w5': 0.12003056875198267,
# 'w6': 0.0,
# 'w7': 0.24167088129817757,
# 'w8': 0.0,
# 'w9': 0.0,
# 'w10': 0.7969327001693214,
# 'w11': 0.0,
# 'w12': 0.2749967725687132,
# 'w13': 0.0,
# 'w14': 0.0,
# 'w15': 0.2378516441435042, 
# 'w16': 0.0,
# 'w17': 0.14678862430514258,
# 'w18': 0.2668292826006618,
# 'w19': 0.19506336648816086,
# }



# syntax_params = {
# 'w1': 0.0,
# 'w2': 0.8482568221158071,
# 'w3': 0.23586797388252334,
# 'w4': 0.44074488598438605,
# 'w5': 0.21261033812882113,
# 'w6': 0.10599413283574514,
# 'w7': 0.1258853825948904,
# 'w8': 0.06530639444552416,
# 'w9': 0.1949413012276045,
# 'w10': 0.0,
# 'w11': 0.24195071354042721,
# 'w12': 0.3002164081973451,
# 'w13': 0.018115063903995497,
# 'w14': 0.0,
# 'w15': 0.0, 
# 'w16': 0.0,
# 'w17': 0.05090581708349936,
# 'w18': 0.0,
# 'w19': 0.28849936372417606,
# }


# vocabulary_params = {
# 'w1': 0.0,
# 'w2': 0.9809382964691326,
# 'w3': 0.2721407500328885,
# 'w4': 0.09234985469200463,
# 'w5': 0.1576625209132273,
# 'w6': 0.0,
# 'w7': 0.28600141532122214,
# 'w8': 0.0,
# 'w9': 0.0,
# 'w10': 0.0,
# 'w11': 0.8348749898016451,
# 'w12': 0.4687944548417954,
# 'w13': 0.0,
# 'w14': 0.0,
# 'w15': 0.0, 
# 'w16': 0.21229471724051416,
# 'w17': 0.0,
# 'w18': 0.40516468231925834,
# 'w19': 0.005605242072024025,
# }


# phraseology_params = {
# 'w1': 0.40938519620940833,
# 'w2': 0.32037874314056886,
# 'w3': 0.3600463660072271,
# 'w4': 0.15257583589489135,
# 'w5': 0.1435280239876074,
# 'w6': 0.0,
# 'w7': 0.25715378983907616,
# 'w8': 0.0592775185888329,
# 'w9': 0.16646038278214906,
# 'w10': 0.0,
# 'w11': 0.6177766714579664,
# 'w12': 0.06460575281108942,
# 'w13': 0.05613701895503964,
# 'w14': 0.0,
# 'w15': 0.0,
# 'w16': 0.0,
# 'w17': 0.09562980191848638,
# 'w18': 0.12357743167147585,
# 'w19': 0.18783363348662874,
# }


# grammar_params = {
# 'w1': 0.14958952407952508,
# 'w2': 0.6647186203882494,
# 'w3': 0.449548924059724,
# 'w4': 0.0,
# 'w5': 0.0,
# 'w6': 0.0,
# 'w7': 0.17948357028693315,
# 'w8': 0.19411977625456364,
# 'w9':  0.0,
# 'w10': 0.6059328388312332,
# 'w11': 0.9999991120158438,
# 'w12': 0.2802250949790587,
# 'w13': 0.0,
# 'w14': 0.5641886830643286,
# 'w15': 0.9366227900298044,  
# 'w16': 0.0,
# 'w17': 0.0,
# 'w18': 0.0,
# 'w19': 0.0
# }



# conventions_params = {
# 'w1': 0.5421236995472959,
# 'w2': 0.7756881225885318,
# 'w3': 0.0,
# 'w4': 0.08166716069359709,
# 'w5': 0.09349444929566797,
# 'w6': 0.10801091873051911,
# 'w7': 0.002436522839725928,
# 'w8': 0.0,
# 'w9': 0.0,
# 'w10': 0.45137404386875285,
# 'w11': 0.20780017578040932,
# 'w12': 0.09884185696917572,
# 'w13': 0.21101659030105996,
# 'w14': 0.0,
# 'w15': 0.0,
# 'w16': 0.024280211512952857,
# 'w17': 0.15845791251604918,
# 'w18': 0.0,
# 'w19': 0.07920878198822079,
# }

# %%
# params = {'w1': 0.3641417002166592, 'w2': 0.9417158372641459, 'w3': 0.2746622153677299}

# %%
params_arr = [
    cohesion_params, syntax_params, vocabulary_params, phraseology_params, grammar_params, conventions_params
]

# params_arr = [
#     params, params, params, params, params, params
# ]


final_preds = np.zeros((all_preds[0].shape[0], all_preds[0].shape[1]))
target_cols=['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']

for idx, val in enumerate(target_cols):
    params = params_arr[idx]
    preds = None
    for index, val in enumerate(params.keys()):
        if index == 0:
            preds = params[val]*all_preds[0][:, idx]
        else:
            preds += params[val]*all_preds[index][:, idx]
    
    param_sum = 0
    for key, val in params.items():
        param_sum += val
    
    preds = preds/param_sum    
    final_preds[:, idx] = preds

# %%
score, scores = get_score(labels, final_preds) 
print(score, scores)
# Out:
# 0.44073070357605065 [0.4668293697639808, 0.4354889855406554, 0.40423453864453823, 0.44530228742612604, 0.4591302258672986, 0.4333988142137049]

# %%
df = pd.read_csv(csvs1[0])
df = df.sort_values('text_id').reset_index(drop=True)

df[[f"pred_{c}" for c in target_cols]] = final_preds

df.head()
# Out:
#    Unnamed: 0       text_id  \
# 0         782  0016926B079C
# 1           0  0022683E9EA5
# 2        3129  00299B378633
# 3        2347  003885A45F42
# 4         783  0049B1DF5CCC
#
#                                            full_text  cohesion  syntax  \
# 0  I think that students would benefit from learn...       3.5     3.5
# 1  When a problem is a change you have to let it ...       2.5     2.5
# 2  Dear, Principal\n\nIf u change the school poli...       3.0     3.5
# 3  The best time in life is when you become yours...       4.5     4.5
# 4  Small act of kindness can impact in other peop...       2.5     3.0
#
#    vocabulary  phraseology  grammar  conventions  fold  pred_cohesion  \
# 0         3.0          3.0      4.0          3.0     1       3.026980
# 1         3.0          2.0      2.0          2.5     0       2.748444
# 2         3.0          3.0      3.0          2.5     4       2.870762
# 3         4.5          4.5      4.0          5.0     3       3.740568
# ...

# %%
df.to_csv("oofs_mean_18.csv", index=False)

# %%
# 0.44190161082439533 [0.4683490117611149, 0.43641989092593286, 0.4060363525616717, 0.4461535846033593, 0.46037933754853244, 0.43407148754576036]
# 0.4418866189987783 [0.46831823661451466, 0.4364091506527005, 0.4060329536945348, 0.4461497001036187, 0.46034520276559826, 0.43406447016170324]
# 0.44177442508001885 [0.4679719888984698, 0.4364091506527005, 0.40603233344333106, 0.4461497001036187, 0.4601159498141438, 0.43396742756784906]
# 0.4415220080866839 [0.4679015219838436, 0.43635714363191674, 0.4053987819986359, 0.44584774686752277, 0.4597470426572887, 0.43387981138089554]
# 0.44135114322892394 [0.46764058444927364, 0.43614958104361945, 0.4050170974396232, 0.4458170268100113, 0.4596269140055629, 0.4338556556254532]
# 0.4412149102820157 [0.46751343233391507, 0.43612184430161116, 0.4050149974691121, 0.44578310251728165, 0.45915490572403633, 0.4337011793461378]
# 0.44115487502267753 [0.46751343233391507, 0.43612184430161116, 0.4046971992578483, 0.4457638413172688, 0.45915490572403633, 0.4336780272013855]
# 0.4410627492862049 [0.4672590714948445, 0.43610050793188354, 0.4046971992578483, 0.44569439805618216, 0.45915490572403633, 0.43347041325243435]
# 0.4409999863004484 [0.46706776352664575, 0.43610050793188354, 0.40453272735492596, 0.4456736000127645, 0.45915490572403633, 0.43347041325243435]
# 0.44096085862233153 [0.46698225969736695, 0.43609804683466835, 0.40444852287626465, 0.4456389608409316, 0.45915490572403633, 0.43344245576072155]


# 0.44087025476393515 [0.46686220641964465, 0.4357650111112116, 0.40444848427690067, 0.44556781191809997, 0.45915490572403633, 0.4334231091337173]


# 0.4408142295814608 [0.46691720120469415, 0.43577904563131403, 0.40424546116132465, 0.44539104560371573, 0.45914061467888967, 0.43341200920882694]


# 0.4407856796333322 [0.4669079020392598, 0.43571499785824686, 0.40423453864453823, 0.44531982878337045, 0.4591302258672986, 0.4334065846072793]

# %%
# 0.4440668683009714 vs 0.4435 -> improvement 0.005

# %%
0.4464636966050677 [0.4774522162758472, 0.4409811027238205, 0.41030992074094386, 0.4488400635555907, 0.46349054820628166, 0.4377083281279225]
0.44602233482013226 [0.47190105558596557, 0.4408934582319372, 0.4092328675674622, 0.4521371963226755, 0.464614145700662, 0.4373552855120913]
0.4548325877750256 [0.48417351985249657, 0.44964943139868785, 0.4196981014482707, 0.45464136817614237, 0.4730027405917249, 0.44783036518283115]
0.4588946815387964 [0.4883262818674721, 0.44730911734564865, 0.4217147655816624, 0.45986613364506074, 0.4839236129232686, 0.45222817786966574]
0.4675331302554317 [0.49765214277676595, 0.45645114798273506, 0.4327923793687365, 0.4686475170329412, 0.487983294242493, 0.4616723001289181]
0.459625977367254 [0.4852677930702217, 0.45080661867510013, 0.41889217539605295, 0.4646356430178369, 0.485038479624519, 0.453115154419794]
0.4552821872345407 [0.4825651534399411, 0.4513317835042047, 0.41614874829333803, 0.4570395258009098, 0.47412801741867805, 0.4504798949501726]
0.4556468443398837 [0.48557718773715286, 0.4482798437135163, 0.41852207310638345, 0.45842502727226125, 0.4730020006591489, 0.45007493355083955]
0.4794399774928058 [0.5065103900603344, 0.4673750093659783, 0.43400418748931463, 0.4826846617586993, 0.5116889848409708, 0.4743766314415378]
0.4440083167462163 [0.4698289449701472, 0.4395532868878126, 0.4082701501490815, 0.4491659119264858, 0.4616986744849544, 0.4355329320588165]
0.4482932688575314 [0.4790979720470143, 0.4436159452633494, 0.40986090461217783, 0.449800748991271, 0.4655324025541706, 0.44185163967720503]
0.4649028426673086 [0.4945144764936061, 0.45500879766624525, 0.42194369902584833, 0.46714688581527036, 0.49046215996594716, 0.4603410370369343]

0.453865354909669 [0.48110201249371903, 0.4455250428140379, 0.4211189686220376, 0.4563122270697702, 0.47263103152953717, 0.44650284692891257]
0.4617823752275663 [0.4866492821393369, 0.4545054553042299, 0.4274107984122044, 0.4669081752094095, 0.48012943240376643, 0.45509110789645074]
